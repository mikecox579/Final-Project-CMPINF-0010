# %%
import pandas as pd
import numpy as np

education = pd.read_csv("education.csv")
education.head()
# Out:
#         Neighborhood  Sector # Population (2010)  \
# 0   Allegheny Center         3               933
# 1     Allegheny West         3               462
# 2          Allentown         6             2,500
# 3          Arlington         7             1,869
# 4  Arlington Heights         7               244
#
#   Total Pop, 25 and older (2010)  \
# 0                            609
# 1                            239
# 2                          1,729
# 3                          1,232
# 4                            166
#
#   Edu. Attainment: Less than High School (2010)  \
# 0                                         18.7%
# 1                                          9.2%
# 2                                         23.0%
# 3                                         14.9%
# 4                                         18.1%
#
#   Edu. Attainment: High School Graduate (2010)  \
# 0                                        44.5%
# 1                                        28.9%
# ...

# %%
education[['Neighborhood','Population (2010)',"Edu. Attainment: Bachelor's Degree (2010)", "Edu. Attainment: Postgraduate Degree (2010)"]].sort_values('Population (2010)', ascending = True).head(10)
# Out:
#          Neighborhood Population (2010)  \
# 31          Fairywood             1,002
# 58            Oakwood             1,027
# 80        Summer Hill             1,051
# 6   Bedford Dwellings             1,202
# 57  Northview Heights             1,214
# 64        Polish Hill             1,274
# 32           Fineview             1,285
# 81     Swisshelm Park             1,361
# 89            Windgap             1,369
# 50        Middle Hill             1,707
#
#    Edu. Attainment: Bachelor's Degree (2010)  \
# 31                                     16.3%
# 58                                      6.3%
# 80                                     13.9%
# 6                                      14.2%
# 57                                      0.0%
# 64                                     18.3%
# 32                                      3.7%
# 81                                     26.2%
# 89                                      6.3%
# 50                                      6.7%
#
# ...

# %%
education["Edu. Attainment: Bachelor's Degree (2010)"].str.rstrip('%').astype('float') / 100.0
# Out:
# 0     0.158
# 1     0.448
# 2     0.056
# 3     0.071
# 4     0.078
#       ...
# 85    0.094
# 86    0.267
# 87    0.201
# 88    0.132
# 89    0.063
# Name: Edu. Attainment: Bachelor's Degree (2010), Length: 90, dtype: float64

# %%
education["Population (2010)"].str.replace(",","").astype(float)
# Out:
# 0      933.0
# 1      462.0
# 2     2500.0
# 3     1869.0
# 4      244.0
#        ...
# 85    2669.0
# 86     254.0
# 87    2604.0
# 88    3066.0
# 89    1369.0
# Name: Population (2010), Length: 90, dtype: float64

# %%
education['Total'] = education["Edu. Attainment: Bachelor's Degree (2010)"] * education["Population (2010)"]

# %%
education['Total Pop, 25 and older (2010)'].str.replace(",","").astype(float)
# Out:
# 0      609.0
# 1      239.0
# 2     1729.0
# 3     1232.0
# 4      166.0
#        ...
# 85    1875.0
# 86      86.0
# 87    1036.0
# 88    2408.0
# 89     979.0
# Name: Total Pop, 25 and older (2010), Length: 90, dtype: float64

# %%
education['Est. Pop. Under Poverty (2010)'].str.replace(",","").astype(float)
# Out:
# 0     324.0
# 1      12.0
# 2     630.0
# 3     361.0
# 4     169.0
#       ...
# 85    722.0
# 86      0.0
# 87    758.0
# 88    186.0
# 89     72.0
# Name: Est. Pop. Under Poverty (2010), Length: 90, dtype: float64
