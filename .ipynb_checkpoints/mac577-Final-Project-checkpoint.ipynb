# %%
#importing pandas, numpy, and matplot
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
#importing built environment conditions dataset
bdc_data = pd.read_csv("https://data.wprdc.org/dataset/40188e1c-6d2e-4f20-9391-607bd3054949/resource/61a264ec-a537-42de-91e3-5752d689103d/download/built-enviornment-conditions.csv",
                      index_col="Neighborhood", thousands=',')
bdc_data.head()
# Out:
#                    Sector #  Population (2010)  Land Area (acres)  \
# Neighborhood
# Allegheny Center          3                933              134.4
# Allegheny West            3                462               90.2
# Allentown                 6               2500              188.8
# Arlington                 7               1869              300.8
# Arlington Heights         7                244               84.5
#
#                    Approx. Total # Parcels (2010)  \
# Neighborhood
# Allegheny Center                               67
# Allegheny West                                282
# Allentown                                    1550
# Arlington                                    1049
# Arlington Heights                              10
#
#                    Approx. Total # Taxable Parcels (2010)  \
# Neighborhood
# Allegheny Center                                       26
# Allegheny West                                        234
# Allentown                                            1402
# Arlington                                             950
# Arlington Heights                                       7
#
#                    Approx. # of Structures (2010)  \
# Neighborhood
# Allegheny Center                               58
# Allegheny West                                176
# Allentown                                    1283
# Arlington                                    1034
# Arlington Heights                              13
#
#                    Approx. # Unoccupied Parcels (2010)  \
# Neighborhood
# Allegheny Center                                    15
# Allegheny West                                      49
# Allentown                                          334
# Arlington                                          198
# Arlington Heights                                    4
#
#                   % Good / Excellent Condition Buildings (2009)  \
# Neighborhood
# Allegheny Center                                            NaN
# Allegheny West                                            72.0%
# Allentown                                                  2.5%
# Arlington                                                  0.3%
# Arlington Heights                                           NaN
#
#                   % Average Condition Buildings (2009)  \
# Neighborhood
# Allegheny Center                                   NaN
# Allegheny West                                   22.3%
# Allentown                                        86.9%
# Arlington                                        97.6%
# Arlington Heights                                  NaN
#
#                   % Poor / Derelict Condition Buildings (2009)  ...  \
# Neighborhood                                                    ...
# Allegheny Center                                           NaN  ...
# Allegheny West                                            5.7%  ...
# Allentown                                                10.6%  ...
# Arlington                                                 2.1%  ...
# Arlington Heights                                          NaN  ...
#
#                    $ Residential Bldg. Permits (2010)  \
# Neighborhood
# Allegheny Center                                   $0
# Allegheny West                                $30,784
# Allentown                                    $349,708
# Arlington                                    $159,496
# Arlington Heights                                  $0
#
#                   # Commercial Bldg. Permits (2010)  \
# Neighborhood
# Allegheny Center                                  6
# Allegheny West                                    6
# Allentown                                         1
# Arlington                                         1
# Arlington Heights                                 0
#
#                    $ Commercial Bldg. Permits (2010) # Code Violations (2010)  \
# Neighborhood
# Allegheny Center                          $6,314,000                        0
# Allegheny West                              $795,300                        3
# Allentown                                   $350,000                      175
# Arlington                                    $50,000                      130
# Arlington Heights                                 $0                        0
#
#                    % of all Bldgs. w/ Code Violations (2010)  \
# Neighborhood
# Allegheny Center                                        0.0%
# Allegheny West                                          1.7%
# Allentown                                              13.6%
# Arlington                                              12.6%
# Arlington Heights                                       0.0%
#
#                   # Condemned Structures (2010)  \
# Neighborhood
# Allegheny Center                              0
# Allegheny West                                1
# Allentown                                    30
# Arlington                                    10
# Arlington Heights                             0
#
#                    % of all Bldgs. Condemned (2010) # Demolitions (2010)  \
# Neighborhood
# Allegheny Center                               0.0%                    0
# Allegheny West                                 0.6%                    0
# Allentown                                      2.3%                   16
# Arlington                                      1.0%                    7
# Arlington Heights                              0.0%                    0
#
#                    # Tax Delinquent Prop. (2+ yrs.) (2010)  \
# Neighborhood
# Allegheny Center                                         0
# Allegheny West                                           3
# Allentown                                              287
# Arlington                                              142
# Arlington Heights                                        3
#
#                    % of Taxable Prop. Delinquent (2010)
# Neighborhood
# Allegheny Center                                   0.0%
# Allegheny West                                     1.3%
# Allentown                                         20.5%
# Arlington                                         14.9%
# Arlington Heights                                 42.9%
#
# [5 rows x 21 columns]

# %% [markdown]
# This is our dataset that we will be working with for our built environment conditions metric.
#
# Specifically we will be looking at the number of code violations per neighborhood to determine the best neighborhood. Approximate number of structures will also be taken into account as areas with more buildings are subjected to more code violations.

# %%
code_violations = bdc_data.loc[:,["# Code Violations (2010)"]]
code_violations_sorted = code_violations["# Code Violations (2010)"].sort_values(ascending=True)
code_violations_sorted.head()
# Out:
# Neighborhood
# Allegheny Center     0
# Glen Hazel           0
# Northview Heights    0
# Arlington Heights    0
# Regent Square        1
# Name: # Code Violations (2010), dtype: int64

# %% [markdown]
# This is our sorted code violations from the neighborhood with the least number of violations to the most. This shows us that there are four neighborhoods with no violations: Allegheny Center, Glen Hazel, Northview Heights, and Arlington Heights.

# %%
num_structures = bdc_data.loc[:, ["Approx. # of Structures (2010)"]].astype(int)
num_structures_sorted = num_structures["Approx. # of Structures (2010)"].sort_values(ascending=True)
num_structures_sorted.head()
# Out:
# Neighborhood
# Arlington Heights    13
# North Shore          41
# Allegheny Center     58
# South Shore          63
# Glen Hazel           65
# Name: Approx. # of Structures (2010), dtype: int64

# %% [markdown]
# This is our sorted population from the neighborhood with the least number of structures to the most structures. This shows us that some of the neighborhoods with the least number of code violations are also the neighborhoods with the least number of structures.

# %%
# shows us the bar graph for code violations per neighborhood
code_violations.plot(kind="bar", title="Code Violations vs Neighborhood", figsize=(20, 10))
plt.ylabel("# of Code Violations")
# Out:
# Text(0, 0.5, '# of Code Violations')

# %%
# shows us the bar graph for the number of structures per neighborhood
num_structures.plot(kind="bar", title="Approximate # of Structures vs Neighborhood", figsize=(20, 10))
plt.ylabel("Approx. # of Structures")
# Out:
# Text(0, 0.5, 'Approx. # of Structures')

# %% [markdown]
# As mentioned before we have four neighborhoods with no violations: Allegheny Center, Glen Hazel, Northview Heights, and Arlington Heights. As you can see below Northview Heights has the most structures between the four with no violations making it our best neighborhood.

# %%
# calculating ratio for # of Code Violations / Approx. # of Structures
ratio_totals = code_violations.loc[:, "# Code Violations (2010)"].div(num_structures.loc[:, "Approx. # of Structures (2010)"])
ratio_totals_sorted = ratio_totals.sort_values(ascending=True)

# eliminating outliers with a ratio score of 0
ratio_totals_sorted = ratio_totals_sorted.loc["Regent Square" : "West Oakland"]

ratio_totals_sorted.head()
# Out:
# Neighborhood
# Regent Square      0.001623
# Swisshelm Park     0.007802
# Terrace Village    0.008949
# Banksville         0.010724
# Oakwood            0.012255
# dtype: float64

# %%
ratio_totals_sorted.tail()
# Out:
# Neighborhood
# South Oakland      0.244845
# Homewood South     0.263889
# Central Oakland    0.320099
# Mt. Oliver         0.335793
# West Oakland       0.357143
# dtype: float64

# %%
ratio_totals_sorted.plot(kind="bar", title="Ratio vs Neighborhood", figsize=(20, 10))
plt.ylabel("Ratio")
# Out:
# Text(0, 0.5, 'Ratio')

# %% [markdown]
# ## Conclusion
#
# In conclusion Regent Square is the best neighborhood by its number of code violations per building. My top 5 neighborhoods included Regent Square, Swisshelm Park, Terrace Village, Banksville, and Oakwood. I took the number total number of code violations for each neighborhood and divided it by the approximate number of structures in each neighborhood. I noticed that some neighborhoods had 0 code violations with under 50 buildings, so I considered them to be outliers and removed those neighborhoods.
#
# Best: Regent Square
#
# Worst: West Oakland
