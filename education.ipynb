# %%
import pandas as pd
import numpy as np

education = pd.read_csv("education.csv", index_col="Neighborhood", thousands = ",")
education.head()
# Out:
#                    Sector #  Population (2010)  \
# Neighborhood
# Allegheny Center          3                933
# Allegheny West            3                462
# Allentown                 6               2500
# Arlington                 7               1869
# Arlington Heights         7                244
#
#                    Total Pop, 25 and older (2010)  \
# Neighborhood
# Allegheny Center                              609
# Allegheny West                                239
# Allentown                                    1729
# Arlington                                    1232
# Arlington Heights                             166
#
#                   Edu. Attainment: Less than High School (2010)  \
# Neighborhood
# Allegheny Center                                          18.7%
# Allegheny West                                             9.2%
# Allentown                                                 23.0%
# Arlington                                                 14.9%
# Arlington Heights                                         18.1%
#
#                   Edu. Attainment: High School Graduate (2010)  \
# Neighborhood
# Allegheny Center                                         44.5%
# Allegheny West                                           28.9%
# Allentown                                                63.3%
# Arlington                                                65.3%
# Arlington Heights                                        74.1%
#
#                   Edu. Attainment: Assoc./Prof. Degree (2010)  \
# Neighborhood
# Allegheny Center                                        17.2%
# Allegheny West                                           6.7%
# Allentown                                                6.6%
# Arlington                                               10.1%
# Arlington Heights                                        0.0%
#
#                   Edu. Attainment: Bachelor's Degree (2010)  \
# Neighborhood
# Allegheny Center                                      15.8%
# Allegheny West                                        44.8%
# Allentown                                              5.6%
# Arlington                                              7.1%
# Arlington Heights                                      7.8%
#
#                   Edu. Attainment: Postgraduate Degree (2010)  \
# Neighborhood
# Allegheny Center                                         3.8%
# Allegheny West                                          10.5%
# Allentown                                                1.5%
# Arlington                                                2.5%
# Arlington Heights                                        0.0%
#
#                   1999 Median Income ('99 Dollars)  \
# Neighborhood
# Allegheny Center                          $16,964
# Allegheny West                            $26,638
# Allentown                                 $22,539
# Arlington                                 $27,167
# Arlington Heights                         $18,646
#
#                   2009 Median Income ('09 Dollars)  \
# Neighborhood
# Allegheny Center                          $20,911
# Allegheny West                            $41,761
# Allentown                                 $29,274
# Arlington                                 $25,119
# Arlington Heights                          $9,417
#
#                   1999 Median Income ('11 Dollars)  \
# Neighborhood
# Allegheny Center                          $22,535
# Allegheny West                            $35,386
# Allentown                                 $29,941
# Arlington                                 $36,089
# Arlington Heights                         $24,769
#
#                   2009 Med. Income ('13 Dollars)  \
# Neighborhood
# Allegheny Center                        $22,793
# Allegheny West                          $45,519
# Allentown                               $31,909
# Arlington                               $27,380
# Arlington Heights                       $10,265
#
#                    Est. Pop. for which Poverty Calc. (2010)  \
# Neighborhood
# Allegheny Center                                        954
# Allegheny West                                          239
# Allentown                                              2212
# Arlington                                              1779
# Arlington Heights                                       293
#
#                    Est. Pop. Under Poverty (2010)  \
# Neighborhood
# Allegheny Center                              324
# Allegheny West                                 12
# Allentown                                     630
# Arlington                                     361
# Arlington Heights                             169
#
#                   Est. Percent Under Poverty (2010)
# Neighborhood
# Allegheny Center                              34.0%
# Allegheny West                                 5.0%
# Allentown                                     28.5%
# Arlington                                     20.3%
# Arlington Heights                             57.7%

# %%
education[['Population (2010)',"Edu. Attainment: Bachelor's Degree (2010)", "Edu. Attainment: Postgraduate Degree (2010)"]].sort_values('Population (2010)', ascending = True).head(10)
# Out:
#                    Population (2010)  \
# Neighborhood
# Chateau                           11
# South Shore                       19
# St. Clair                        209
# Arlington Heights                244
# West End                         254
# Esplen                           301
# North Shore                      303
# Hays                             362
# Allegheny West                   462
# Chartiers City                   477
#
#                   Edu. Attainment: Bachelor's Degree (2010)  \
# Neighborhood
# Chateau                                                 NaN
# South Shore                                            0.0%
# St. Clair                                              4.6%
# Arlington Heights                                      7.8%
# West End                                              26.7%
# Esplen                                                 0.0%
# North Shore                                            5.6%
# Hays                                                   6.6%
# Allegheny West                                        44.8%
# Chartiers City                                        10.6%
#
#                   Edu. Attainment: Postgraduate Degree (2010)
# Neighborhood
# Chateau                                                   NaN
# South Shore                                             47.6%
# St. Clair                                                0.0%
# Arlington Heights                                        0.0%
# West End                                                 0.0%
# Esplen                                                   6.3%
# North Shore                                             28.6%
# Hays                                                     0.0%
# Allegheny West                                          10.5%
# Chartiers City                                           7.0%

# %%
educationPer = education.loc[:, "Edu. Attainment: Bachelor's Degree (2010)"].str.rstrip('%').astype('float')/100
educationPer.head()
# Out:
# Neighborhood
# Allegheny Center     0.158
# Allegheny West       0.448
# Allentown            0.056
# Arlington            0.071
# Arlington Heights    0.078
# Name: Edu. Attainment: Bachelor's Degree (2010), dtype: float64

# %%
education["Population (2010)"]
# Out:
# Neighborhood
# Allegheny Center        933
# Allegheny West          462
# Allentown              2500
# Arlington              1869
# Arlington Heights       244
#                        ...
# Upper Lawrenceville    2669
# West End                254
# West Oakland           2604
# Westwood               3066
# Windgap                1369
# Name: Population (2010), Length: 90, dtype: int64

# %%
educationPopulation = educationPer.multiply(education.loc[:,"Population (2010)"])

# %%
educationPopulation.head()
# Out:
# Neighborhood
# Allegheny Center     147.414
# Allegheny West       206.976
# Allentown            140.000
# Arlington            132.699
# Arlington Heights     19.032
# dtype: float64
