# %%
import pandas as pd
import numpy as np

education = pd.read_csv("education.csv", thousands = ",")
education.head()
# Out:
#         Neighborhood  Sector #  Population (2010)  \
# 0   Allegheny Center         3                933
# 1     Allegheny West         3                462
# 2          Allentown         6               2500
# 3          Arlington         7               1869
# 4  Arlington Heights         7                244
#
#    Total Pop, 25 and older (2010)  \
# 0                             609
# 1                             239
# 2                            1729
# 3                            1232
# 4                             166
#
#   Edu. Attainment: Less than High School (2010)  \
# 0                                         18.7%
# 1                                          9.2%
# 2                                         23.0%
# 3                                         14.9%
# 4                                         18.1%
#
#   Edu. Attainment: High School Graduate (2010)  \
# 0                                        44.5%
# 1                                        28.9%
# ...

# %%
education[['Neighborhood','Population (2010)',"Edu. Attainment: Bachelor's Degree (2010)", "Edu. Attainment: Postgraduate Degree (2010)"]].sort_values('Population (2010)', ascending = True).head(10)
# Out:
#          Neighborhood  Population (2010)  \
# 21            Chateau                 11
# 70        South Shore                 19
# 77          St. Clair                209
# 4   Arlington Heights                244
# 86           West End                254
# 30             Esplen                301
# 56        North Shore                303
# 37               Hays                362
# 1      Allegheny West                462
# 20     Chartiers City                477
#
#    Edu. Attainment: Bachelor's Degree (2010)  \
# 21                                       NaN
# 70                                      0.0%
# 77                                      4.6%
# 4                                       7.8%
# 86                                     26.7%
# 30                                      0.0%
# 56                                      5.6%
# 37                                      6.6%
# 1                                      44.8%
# 20                                     10.6%
#
# ...

# %%
education["Edu. Attainment: Bachelor's Degree (2010)"] = education["Edu. Attainment: Bachelor's Degree (2010)"].str.rstrip('%').astype('float')/100
education["Edu. Attainment: Bachelor's Degree (2010)"].head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-6fea3b3ae9bf> in <module>
# ----> 1 education["Edu. Attainment: Bachelor's Degree (2010)"] = education["Edu. Attainment: Bachelor's Degree (2010)"].str.rstrip('%').astype('float')/100
#       2 education["Edu. Attainment: Bachelor's Degree (2010)"].head()
#
# /opt/tljh/user/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5268             or name in self._accessors
#    5269         ):
# -> 5270             return object.__getattribute__(self, name)
#    5271         else:
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# /opt/tljh/user/lib/python3.8/site-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     185             # we're accessing the attribute of the class, i.e., Dataset.geo
# ...

# %%
education["Population (2010)"]
# Out:
# 0      933
# 1      462
# 2     2500
# 3     1869
# 4      244
#       ...
# 85    2669
# 86     254
# 87    2604
# 88    3066
# 89    1369
# Name: Population (2010), Length: 90, dtype: int64

# %%
educationPopulation = education.loc[:, "Edu. Attainment: Bachelor's Degree (2010)"].multiply(education.loc[:,"Population (2010)"])

# %%
educationPopulation.head()
# Out:
# 0    15.8%15.8%15.8%15.8%15.8%15.8%15.8%15.8%15.8%1...
# 1    44.8%44.8%44.8%44.8%44.8%44.8%44.8%44.8%44.8%4...
# 2    5.6%5.6%5.6%5.6%5.6%5.6%5.6%5.6%5.6%5.6%5.6%5....
# 3    7.1%7.1%7.1%7.1%7.1%7.1%7.1%7.1%7.1%7.1%7.1%7....
# 4    7.8%7.8%7.8%7.8%7.8%7.8%7.8%7.8%7.8%7.8%7.8%7....
# dtype: object
